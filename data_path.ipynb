# %%
### test file for testing program 
testfile = {"test10":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/True/test10.paf",
            "testdep":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/True/testdepth.paf"
}

test_feather={
    "test10":"zymo_feather/test10.feather",
    "testdep":"zymo_feather/testdep.feather"
}

### unique map files
umap_files = {
    "BBv2":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/True/nosamuniq_map.paf",
    "BigBBv2":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/Big/uniq_map.paf",
    "BBR10v2":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/R10/uniq_map.paf",
    "HybridR10v2":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/newR10/uniq_map.paf",             
    "BBv1":"/big6_disk/fangren106/mock_community/v1_zymo/BB/alignment/uniq_map.paf",
    "Hybridv1":"/big6_disk/fangren106/mock_community/v1_zymo/Hybrid-BB_MPZ/alignment/uniq_map.paf"
}

### unique map & trimmed files
trim_files = {
    "BBv2_trim900":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/True/trim900_uniq_map.paf",
    "BigBBv2_trim900":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/Big/trim900_uniq_map.paf",
    "BBR10v2_trim1050":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/R10/trim1050_uniq_map.paf",
    "HybridR10v2_trim400":"/big6_disk/fangren106/mock_community/v2_zymo/even/alignment/newR10/trim400_uniq_map.paf",
    "BBv1_trim500":"/big6_disk/fangren106/mock_community/v1_zymo/BB/alignment/trim500_uniq_map.paf",
    "Hybridv1_trim550":"/big6_disk/fangren106/mock_community/v1_zymo/Hybrid-BB_MPZ/alignment/trim550_uniq_map.paf"
            }

### feather format files
umap_feathers = {
    "BBv2":"zymo_feather/BBv2nosam.feather",
    "BigBBv2":"zymo_feather/BigBBv2.feather",
    "BBR10v2":"zymo_feather/BBR10v2.feather",
    "HybridR10v2":"zymo_feather/HybridR10v2.feather",             
    "BBv1":"zymo_feather/BBv1.feather",
    "Hybridv1":"zymo_feather/Hybridv1.feather"
}

other_feathers={
    "BBv2_sam":"zymo_feather/BBv2.feather",
    "BBv2_nosam":"zymo_feather/BBv2nosam.feather"
}

trim_feathers = {
    "BBv2_trim900":"zymo_feather/BBv2_trim900.feather",
    "BigBBv2_trim900":"zymo_feather/BigBBv2_trim900.feather",
    "BBR10v2_trim1050":"zymo_feather/BBR10v2_trim1050.feather",
    "HybridR10v2_trim400":"zymo_feather/HybridR10v2_trim400.feather",
    "BBv1_trim500":"zymo_feather/BBv1_trim500.feather",
    "Hybridv1_trim550":"zymo_feather/Hybridv1_trim550.feather"
}

umap_norm_feather={
    "div_total_minus_true":""
    
}



### gram strain species name
gram_pos = ("Lactobacillus", "Bacillus", "Listeria", "Staphylococcus", "Enterococcus")
gram_neg = ("Salmonella", "Escherichia", "Pseudomonas")
fungi = ("Cryptococcus", "Saccharomyces")
